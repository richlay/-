# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
f = open('./tete.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# 27

# %%
strEx = " ".join(str(x) for x in ex)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(strEx)
sent
# Out:
# [('Consumer', 'NN'),
#  ('Beware', 'NNP'),
#  (':', ':'),
#  ('With', 'IN'),
#  ('Less', 'NNP'),
#  ('Trade', 'NNP'),
#  ('Comes', 'NNP'),
#  ('Less', 'NNP'),
#  ('Choice', 'NNP'),
#  (';', ':'),
#  ('Imports', 'NNS'),
#  ('take', 'VBP'),
#  ('blame', 'NN'),
#  ('for', 'IN'),
#  ('demise', 'NN'),
#  ('of', 'IN'),
#  ('U.S.', 'NNP'),
#  ('car', 'NN'),
#  ('brands', 'NNS'),
#  (',', ','),
#  ('but', 'CC'),
#  ('overall', 'JJ'),
#  ('variety', 'NN'),
#  ('expands', 'VBZ'),
#  ('economy', 'NN'),
#  ('If', 'IN'),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('shrinking', 'VBG'),
#  ('share', 'NN'),
#  ('of', 'IN'),
#  ('Americans', 'NNPS'),
#  ('who', 'WP'),
#  ('still', 'RB'),
#  ('prefer', 'VBP'),
#  ('cars', 'NNS'),
#  ('to', 'TO'),
#  ('trucks', 'NNS'),
#  ('or', 'CC'),
#  ('SUVs', 'NNP'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('some', 'DT'),
#  ('bad', 'JJ'),
#  ('news', 'NN'),
#  (':', ':'),
#  ('Your', 'PRP$'),
#  ('world', 'NN'),
#  ('is', 'VBZ'),
#  ('getting', 'VBG'),
#  ('smaller', 'JJR'),
#  ('.', '.'),
#  ('Just', 'NNP'),
#  ('two', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('could', 'MD'),
#  ('choose', 'VB'),
#  ('from', 'IN'),
#  ('90', 'CD'),
#  ('different', 'JJ'),
#  ('models', 'NNS'),
#  (',', ','),
#  ('from', 'IN'),
#  ('large', 'JJ'),
#  ('to', 'TO'),
#  ('subcompact', 'VB'),
#  ('.', '.'),
#  ('By', 'IN'),
#  ('next', 'JJ'),
#  ('year', 'NN'),
#  (',', ','),
#  ('that', 'WDT'),
#  ('will', 'MD'),
#  ('shrivel', 'VB'),
#  ('to', 'TO'),
#  ('just', 'RB'),
#  ('62', 'CD'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('cars', 'NNS'),
#  ('that', 'WDT'),
#  ('will', 'MD'),
#  ('disappear', 'VB'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('lineup', 'NN'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('General', 'NNP'),
#  ('Motors', 'NNPS'),
#  ('Co.', 'NNP'),
#  ("'s", 'POS'),
#  ('Chevrolet', 'NNP'),
#  ('Cruze', 'NNP'),
#  ('and', 'CC'),
#  ('Ford', 'NNP'),
#  ('Motor', 'NNP'),
#  ('Co.', 'NNP'),
#  ("'s", 'POS'),
#  ('Focus', 'NNP'),
#  (',', ','),
#  ('will', 'MD'),
#  ('still', 'RB'),
#  ('be', 'VB'),
#  ('manufactured', 'VBN'),
#  ('and', 'CC'),
#  ('sold', 'VBN'),
#  ('overseas', 'RB'),
#  (';', ':'),
#  ('they', 'PRP'),
#  ('just', 'RB'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('be', 'VB'),
#  ('available', 'JJ'),
#  ('to', 'TO'),
#  ('Americans', 'NNPS'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('mostly', 'RB'),
#  ('reflects', 'VBZ'),
#  ('a', 'DT'),
#  ('strategic', 'JJ'),
#  ('choice', 'NN'),
#  (':', ':'),
#  ('GM', 'NNP'),
#  (',', ','),
#  ('Ford', 'NNP'),
#  ('and', 'CC'),
#  ('Fiat', 'NNP'),
#  ('Chrysler', 'NNP'),
#  ('Automobiles', 'NNP'),
#  ('NV', 'NNP'),
#  ('have', 'VBP'),
#  ('concluded', 'VBN'),
#  ('their', 'PRP$'),
#  ('capital', 'NN'),
#  ('is', 'VBZ'),
#  ('better', 'RBR'),
#  ('invested', 'VBN'),
#  ('in', 'IN'),
#  ('expanding', 'VBG'),
#  ('their', 'PRP$'),
#  ('lineup', 'NN'),
#  ('of', 'IN'),
#  ('high-margin', 'NN'),
#  ('trucks', 'NNS'),
#  ('and', 'CC'),
#  ('SUVs', 'NNP'),
#  ('and', 'CC'),
#  ('electric', 'JJ'),
#  ('and', 'CC'),
#  ('autonomous', 'JJ'),
#  ('cars', 'NNS'),
#  (',', ','),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('in', 'IN'),
#  ('passenger', 'NN'),
#  ('cars', 'NNS'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('sales', 'NNS'),
#  ('are', 'VBP'),
#  ('sinking', 'VBG'),
#  ('and', 'CC'),
#  ('profits', 'NNS'),
#  ('are', 'VBP'),
#  ('razor-thin', 'JJ'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('margin', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('shift', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('direction', 'NN'),
#  ('of', 'IN'),
#  ('globalization', 'NN'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('at', 'IN'),
#  ('work', 'NN'),
#  ('.', '.'),
#  ('Falling', 'VBG'),
#  ('trade', 'NN'),
#  ('barriers', 'NNS'),
#  ('enabled', 'VBD'),
#  ('multinational', 'JJ'),
#  ('companies', 'NNS'),
#  ('to', 'TO'),
#  ('integrate', 'VB'),
#  ('their', 'PRP$'),
#  ('supply', 'NN'),
#  ('chains', 'NNS'),
#  ('and', 'CC'),
#  ('rationalize', 'VB'),
#  ('operations', 'NNS'),
#  ('across', 'IN'),
#  ('borders', 'NNS'),
#  (',', ','),
#  ('to', 'TO'),
#  ('minimize', 'VB'),
#  ('costs', 'NNS'),
#  ('and', 'CC'),
#  ('maximize', 'VB'),
#  ('product', 'NN'),
#  ('offerings', 'NNS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('process', 'NN'),
#  (',', ','),
#  ('some', 'DT'),
#  ('American', 'JJ'),
#  ('factory', 'NN'),
#  ('workers', 'NNS'),
#  ('lost', 'VBD'),
#  ('their', 'PRP$'),
#  ('jobs', 'NNS'),
#  ('.', '.'),
#  ('President', 'NNP'),
#  ('Trump', 'NNP'),
#  ('has', 'VBZ'),
#  ('promised', 'VBN'),
#  ('to', 'TO'),
#  ('bring', 'VB'),
#  ('them', 'PRP'),
#  ('back', 'RB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('autos', 'NNS'),
#  ('have', 'VBP'),
#  ('long', 'RB'),
#  ('been', 'VBN'),
#  ('a', 'DT'),
#  ('priority', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('has', 'VBZ'),
#  ('reworked', 'VBN'),
#  ('trade', 'NN'),
#  ('treaties', 'NNS'),
#  ('to', 'TO'),
#  ('raise', 'VB'),
#  ('the', 'DT'),
#  ('bar', 'NN'),
#  ('for', 'IN'),
#  ('tariff-free', 'JJ'),
#  ('imports', 'NNS'),
#  ('and', 'CC'),
#  ('harangued', 'VBN'),
#  ('manufacturers', 'NNS'),
#  ('who', 'WP'),
#  ('cut', 'VBD'),
#  ('production', 'NN'),
#  ('at', 'IN'),
#  ('home', 'NN'),
#  ('while', 'IN'),
#  ('boosting', 'VBG'),
#  ('it', 'PRP'),
#  ('abroad', 'RB'),
#  ('.', '.'),
#  ('On', 'IN'),
#  ('Wednesday', 'NNP'),
#  (',', ','),
#  ('responding', 'VBG'),
#  ('to', 'TO'),
#  ('GM', 'NNP'),
#  ("'s", 'POS'),
#  ('decision', 'NN'),
#  ('to', 'TO'),
#  ('idle', 'VB'),
#  ('several', 'JJ'),
#  ('U.S.', 'NNP'),
#  ('factories', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('one', 'CD'),
#  ('in', 'IN'),
#  ('Ohio', 'NNP'),
#  ('that', 'WDT'),
#  ('makes', 'VBZ'),
#  ('the', 'DT'),
#  ('Cruze', 'NNP'),
#  (',', ','),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('renewed', 'VBD'),
#  ('a', 'DT'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('impose', 'VB'),
#  ('25', 'CD'),
#  ('%', 'NN'),
#  ('tariffs', 'NNS'),
#  ('on', 'IN'),
#  ('all', 'DT'),
#  ('imported', 'VBN'),
#  ('cars', 'NNS'),
#  (',', ','),
#  ('predicting', 'NN'),
#  (',', ','),
#  ('``', '``'),
#  ('many', 'JJ'),
#  ('more', 'JJR'),
#  ('cars', 'NNS'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('built', 'VBN'),
#  ('here', 'RB'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Yet', 'RB'),
#  ('many', 'JJ'),
#  ('now-imported', 'JJ'),
#  ('models', 'NNS'),
#  ('would', 'MD'),
#  ('sell', 'VB'),
#  ('too', 'RB'),
#  ('few', 'JJ'),
#  ('units', 'NNS'),
#  ('to', 'TO'),
#  ('justify', 'VB'),
#  ('domestic', 'JJ'),
#  ('production', 'NN'),
#  (',', ','),
#  ('so', 'RB'),
#  ('showroom', 'JJ'),
#  ('selection', 'NN'),
#  ('would', 'MD'),
#  ('almost', 'RB'),
#  ('certainly', 'RB'),
#  ('shrink', 'VBP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('traditional', 'JJ'),
#  ('case', 'NN'),
#  ('for', 'IN'),
#  ('trade', 'NN'),
#  ('was', 'VBD'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('lets', 'VBZ'),
#  ('countries', 'NNS'),
#  ('specialize', 'VB'),
#  ('where', 'WRB'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ('a', 'DT'),
#  ('comparative', 'JJ'),
#  ('advantage', 'NN'),
#  (':', ':'),
#  ('Portugal', 'NNP'),
#  ('in', 'IN'),
#  ('wine', 'NN'),
#  (',', ','),
#  ('England', 'NNP'),
#  ('in', 'IN'),
#  ('cloth', 'NN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('it', 'PRP'),
#  ('turns', 'VBZ'),
#  ('out', 'RP'),
#  ('that', 'IN'),
#  ('countries', 'NNS'),
#  ('benefit', 'VBP'),
#  ('even', 'RB'),
#  ('more', 'JJR'),
#  ('by', 'IN'),
#  ('trading', 'NN'),
#  ('similar', 'JJ'),
#  ('products', 'NNS'),
#  ('because', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('great', 'JJ'),
#  ('value', 'NN'),
#  ('consumers', 'NNS'),
#  ('place', 'VBP'),
#  ('on', 'IN'),
#  ('variety', 'NN'),
#  ('.', '.'),
#  ('Americans', 'NNPS'),
#  ('are', 'VBP'),
#  ('much', 'RB'),
#  ('more', 'RBR'),
#  ('likely', 'JJ'),
#  ('to', 'TO'),
#  ('find', 'VB'),
#  ('the', 'DT'),
#  ('perfect', 'JJ'),
#  ('fit', 'NN'),
#  ('for', 'IN'),
#  ('their', 'PRP$'),
#  ('tastes', 'NNS'),
#  ('if', 'IN'),
#  ('their', 'PRP$'),
#  ('choices', 'NNS'),
#  ('include', 'VBP'),
#  ('Scotch', 'NNP'),
#  ('whisky', 'NN'),
#  (',', ','),
#  ('French', 'JJ'),
#  ('cheese', 'NN'),
#  ('and', 'CC'),
#  ('Scandinavian', 'JJ'),
#  ('crime', 'NN'),
#  ('fiction', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('especially', 'RB'),
#  ('true', 'JJ'),
#  ('with', 'IN'),
#  ('products', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('cars', 'NNS'),
#  ('that', 'IN'),
#  ('require', 'VBP'),
#  ('steep', 'JJ'),
#  ('up-front', 'JJ'),
#  ('investments', 'NNS'),
#  ('and', 'CC'),
#  ('economies', 'NNS'),
#  ('of', 'IN'),
#  ('scale', 'NN'),
#  (':', ':'),
#  ('A', 'DT'),
#  ('larger', 'JJR'),
#  ('transnational', 'JJ'),
#  ('market', 'NN'),
#  ('can', 'MD'),
#  ('support', 'VB'),
#  ('more', 'JJR'),
#  ('brands', 'NNS'),
#  ('and', 'CC'),
#  ('models', 'NNS'),
#  ('than', 'IN'),
#  ('several', 'JJ'),
#  ('isolated', 'JJ'),
#  ('national', 'JJ'),
#  ('markets', 'NNS'),
#  ('.', '.'),
#  ('Trade', 'NNP'),
#  ('data', 'NN'),
#  ('does', 'VBZ'),
#  ("n't", 'RB'),
#  ('fully', 'RB'),
#  ('capture', 'VB'),
#  ('the', 'DT'),
#  ('benefit', 'NN'),
#  ('of', 'IN'),
#  ('variety', 'NN'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('example', 'NN'),
#  (',', ','),
#  ('if', 'IN'),
#  ('only', 'RB'),
#  ('red', 'JJ'),
#  ('wine', 'NN'),
#  ('is', 'VBZ'),
#  ('made', 'VBN'),
#  ('domestically', 'RB'),
#  (',', ','),
#  ('access', 'NN'),
#  ('to', 'TO'),
#  ('imported', 'VBN'),
#  ('white', 'JJ'),
#  ('is', 'VBZ'),
#  ('quite', 'RB'),
#  ('desirable', 'JJ'),
#  ('--', ':'),
#  ('but', 'CC'),
#  ('tough', 'JJ'),
#  ('to', 'TO'),
#  ('value', 'NN'),
#  ('.', '.'),
#  ('Between', 'JJ'),
#  ('1972', 'CD'),
#  ('and', 'CC'),
#  ('2001', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('range', 'NN'),
#  ('of', 'IN'),
#  ('products', 'NNS'),
#  ('imported', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('grew', 'VBD'),
#  ('fourfold', 'RB'),
#  (',', ','),
#  ('according', 'VBG'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('2004', 'CD'),
#  ('paper', 'NN'),
#  ('by', 'IN'),
#  ('David', 'NNP'),
#  ('Weinstein', 'NNP'),
#  ('of', 'IN'),
#  ('Columbia', 'NNP'),
#  ('University', 'NNP'),
#  ('and', 'CC'),
#  ('Christian', 'NNP'),
#  ('Broda', 'NNP'),
#  (',', ','),
#  ('then', 'RB'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Federal', 'NNP'),
#  ('Reserve', 'NNP'),
#  ('Bank', 'NNP'),
#  ('of', 'IN'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('put', 'VBD'),
#  ('the', 'DT'),
#  ('unmeasured', 'JJ'),
#  ('value', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('increased', 'VBN'),
#  ('variety', 'NN'),
#  ('at', 'IN'),
#  ('2.8', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('gross', 'JJ'),
#  ('domestic', 'JJ'),
#  ('product', 'NN'),
#  ('.', '.'),
#  ('Last', 'JJ'),
#  ('year', 'NN'),
#  ('a', 'DT'),
#  ('team', 'NN'),
#  ('of', 'IN'),
#  ('economists', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('Fed', 'NNP'),
#  ('found', 'VBD'),
#  ('that', 'IN'),
#  ('85', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('increase', 'NN'),
#  ('in', 'IN'),
#  ('imports', 'NNS'),
#  ('from', 'IN'),
#  ('China', 'NNP'),
#  ('between', 'IN'),
#  ('2000', 'CD'),
#  ('and', 'CC'),
#  ('2006', 'CD'),
#  ('came', 'VBD'),
#  ('from', 'IN'),
#  ('products', 'NNS'),
#  ('that', 'WDT'),
#  ('had', 'VBD'),
#  ('never', 'RB'),
#  ('been', 'VBN'),
#  ('imported', 'VBN'),
#  ('before', 'IN'),
#  (',', ','),
#  ('delivering', 'VBG'),
#  ('a', 'DT'),
#  ('substantial', 'JJ'),
#  ('unmeasured', 'JJ'),
#  ('benefit', 'NN'),
#  ('through', 'IN'),
#  ('greater', 'JJR'),
#  ('variety', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('U.S.', 'NNP'),
#  ('car', 'NN'),
#  ('market', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('prime', 'JJ'),
#  ('example', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('benefits', 'NNS'),
#  ('of', 'IN'),
#  ('imported', 'VBN'),
#  ('variety', 'NN'),
#  ('.', '.'),
#  ('Kristin', 'NNP'),
#  ('Dziczek', 'NNP'),
#  (',', ','),
#  ('an', 'DT'),
#  ('economist', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('industry-backed', 'JJ'),
#  ('Center', 'NNP'),
#  ('for', 'IN'),
#  ('Automotive', 'NNP'),
#  ('Research', 'NNP'),
#  (',', ','),
#  ('says', 'VBZ'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('``', '``'),
#  ('unbelievably', 'RB'),
#  ('hard', 'JJ'),
#  ("''", "''"),
#  ('for', 'IN'),
#  ('American', 'JJ'),
#  ('manufacturers', 'NNS'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('cars', 'NNS'),
#  ('profitably', 'RB'),
#  (',', ','),
#  ('no', 'DT'),
#  ('matter', 'NN'),
#  ('how', 'WRB'),
#  ('much', 'RB'),
#  ('they', 'PRP'),
#  ('automate', 'VBP'),
#  ('or', 'CC'),
#  ('what', 'WP'),
#  ('concessions', 'NNS'),
#  ('their', 'PRP$'),
#  ('unions', 'NNS'),
#  ('offer', 'VBP'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('growing', 'VBG'),
#  ('share', 'NN'),
#  ('of', 'IN'),
#  ('cars', 'NNS'),
#  ('is', 'VBZ'),
#  ('thus', 'RB'),
#  ('made', 'VBN'),
#  ('by', 'IN'),
#  ('foreign', 'JJ'),
#  ('companies', 'NNS'),
#  (',', ','),
#  ('imported', 'VBN'),
#  (',', ','),
#  ('or', 'CC'),
#  ('both', 'DT'),
#  ('.', '.'),
#  ('According', 'VBG'),
#  ('to', 'TO'),
#  ('Edmunds.com', 'NNP'),
#  (',', ','),
#  ('19', 'CD'),
#  ('of', 'IN'),
#  ('20', 'CD'),
#  ('subcompact', 'NN'),
#  ('and', 'CC'),
#  ('17', 'CD'),
#  ('of', 'IN'),
#  ('27', 'CD'),
#  ('compact', 'JJ'),
#  ('cars', 'NNS'),
#  ('offered', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('are', 'VBP'),
#  ('imported', 'VBN'),
#  ('.', '.'),
#  ('Early', 'JJ'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ('Ford', 'NNP'),
#  ('scrapped', 'VBD'),
#  ('plans', 'NNS'),
#  ('to', 'TO'),
#  ('move', 'VB'),
#  ('production', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Focus', 'NNP'),
#  ('from', 'IN'),
#  ('Michigan', 'NNP'),
#  ('to', 'TO'),
#  ('Mexico', 'NNP'),
#  ('after', 'IN'),
#  ('criticism', 'NN'),
#  ('from', 'IN'),
#  ('then-President-elect', 'JJ'),
#  ('Trump', 'NNP'),
#  ('.', '.'),
#  ('Ford', 'NNP'),
#  ('then', 'RB'),
#  ('sought', 'VBD'),
#  ('to', 'TO'),
#  ('import', 'VB'),
#  ('it', 'PRP'),
#  ('from', 'IN'),
#  ('an', 'DT'),
#  ('underutilized', 'JJ'),
#  ('plant', 'NN'),
#  ('in', 'IN'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('but', 'CC'),
#  ('dropped', 'VBD'),
#  ('that', 'IN'),
#  ('plan', 'NN'),
#  ('after', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('imposed', 'VBD'),
#  ('a', 'DT'),
#  ('25', 'CD'),
#  ('%', 'NN'),
#  ('tariff', 'NN'),
#  ('on', 'IN'),
#  ('Chinese', 'JJ'),
#  ('imports', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('now', 'RB'),
#  ('plans', 'VBZ'),
#  ('to', 'TO'),
#  ('discontinue', 'VB'),
#  ('offering', 'VBG'),
#  ('the', 'DT'),
#  ('car', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('Last', 'JJ'),
#  ('year', 'NN'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('also', 'RB'),
#  ('lit', 'VBD'),
#  ('into', 'IN'),
#  ('GM', 'NNP'),
#  ('for', 'IN'),
#  ('importing', 'VBG'),
#  ('the', 'DT'),
#  ('Cruze', 'NNP'),
#  ('from', 'IN'),
#  ('Mexico', 'NNP'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('misfire', 'NN'),
#  (':', ':'),
#  ('GM', 'NNP'),
#  ('only', 'RB'),
#  ('imports', 'VBZ'),
#  ('the', 'DT'),
#  ('hatchback', 'NN'),
#  ('version', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('fraction', 'NN'),
#  ('of', 'IN'),
#  ('U.S.', 'NNP'),
#  ('sales', 'NNS'),
#  (',', ','),
#  ('from', 'IN'),
#  ('Mexico', 'NNP'),
#  ('.', '.'),
#  ('Sedans', 'NNS'),
#  ('sold', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('are', 'VBP'),
#  ('made', 'VBN'),
#  ('in', 'IN'),
#  ('Ohio', 'NNP'),
#  ('.', '.'),
#  ('Once', 'NNP'),
#  ('production', 'NN'),
#  ('ends', 'NNS'),
#  (',', ','),
#  ('GM', 'NNP'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('import', 'VB'),
#  ('the', 'DT'),
#  ('Cruze', 'NNP'),
#  (':', ':'),
#  ('It', 'PRP'),
#  ('will', 'MD'),
#  ('just', 'RB'),
#  ('stop', 'VB'),
#  ('selling', 'VBG'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('a', 'DT'),
#  ('question', 'NN'),
#  ('of', 'IN'),
#  ('resource', 'NN'),
#  ('allocation', 'NN'),
#  (':', ':'),
#  ('We', 'PRP'),
#  ("'d", 'MD'),
#  ('rather', 'RB'),
#  ('invest', 'VB'),
#  ('in', 'IN'),
#  ('higher', 'JJR'),
#  ('growth', 'NN'),
#  ('opportunities', 'NNS'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('a', 'DT'),
#  ('spokesman', 'NN'),
#  ('says', 'VBZ'),
#  ('.', '.'),
#  ('Still', 'RB'),
#  (',', ','),
#  ('GM', 'NNP'),
#  ('will', 'MD'),
#  ('continue', 'VB'),
#  ('to', 'TO'),
#  ('sell', 'VB'),
#  ('Mexican-made', 'NNP'),
#  ('Cruzes', 'NNP'),
#  ('in', 'IN'),
#  ('Latin', 'NNP'),
#  ('America', 'NNP'),
#  ('and', 'CC'),
#  ('Israel', 'NNP'),
#  ('and', 'CC'),
#  (',', ','),
#  ('possibly', 'RB'),
#  (',', ','),
#  ('Canada', 'NNP'),
#  ('.', '.'),
#  ('While', 'IN'),
#  ('GM', 'NNP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('cite', 'VB'),
#  ('tariffs', 'NNS'),
#  ('or', 'CC'),
#  ('trade', 'NN'),
#  ('tensions', 'NNS'),
#  ('as', 'IN'),
#  ('driving', 'VBG'),
#  ('its', 'PRP$'),
#  ('decisions', 'NNS'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('clearly', 'RB'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('help', 'VB'),
#  (':', ':'),
#  ('Tariffs', 'VB'),
#  ('on', 'IN'),
#  ('steel', 'NN'),
#  (',', ','),
#  ('aluminum', 'NN'),
#  ('and', 'CC'),
#  ('imported', 'VBN'),
#  ('Chinese', 'JJ'),
#  ('parts', 'NNS'),
#  ('all', 'DT'),
#  ('eat', 'VBP'),
#  ('into', 'IN'),
#  ('what', 'WP'),
#  ('are', 'VBP'),
#  ('already', 'RB'),
#  ('thin', 'JJ'),
#  ('margins', 'NNS'),
#  ('on', 'IN'),
#  ('cars', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('That', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ("'s", 'POS'),
#  ('trade', 'NN'),
#  ('tactics', 'NNS'),
#  ('sometimes', 'RB'),
#  ('hurt', 'VBP'),
#  ('consumers', 'NNS'),
#  ('does', 'VBZ'),
#  ("n't", 'RB'),
#  ('make', 'VB'),
#  ('them', 'PRP'),
#  ('wrong', 'JJ'),
#  (':', ':'),
#  ('It', 'PRP'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('necessary', 'JJ'),
#  ('price', 'NN'),
#  ('if', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('coax', 'VB'),
#  ('foreign', 'JJ'),
#  ('countries', 'NNS'),
#  ('into', 'IN'),
#  ('concessions', 'NNS'),
#  ('that', 'WDT'),
#  ('lower', 'VBP'),
#  ('the', 'DT'),
#  ('barriers', 'NNS'),
#  ('to', 'TO'),
#  ('American', 'JJ'),
#  ('companies', 'NNS'),
#  (',', ','),
#  ('workers', 'NNS'),
#  ('and', 'CC'),
#  ('exporters', 'NNS'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  (',', ','),
#  ('consumers', 'NNS'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('more', 'JJR'),
#  ('to', 'TO'),
#  ('choose', 'VB'),
#  ('from', 'IN'),
#  ('than', 'IN'),
#  ('before', 'IN'),
#  (';', ':'),
#  ('otherwise', 'RB'),
#  (',', ','),
#  ('they', 'PRP'),
#  ("'ll", 'MD'),
#  ('be', 'VB'),
#  ('losers', 'NNS'),
#  ('.', '.')]

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   (NP Consumer/NN)
#   Beware/NNP
#   :/:
#   With/IN
#   Less/NNP
#   Trade/NNP
#   Comes/NNP
#   Less/NNP
#   Choice/NNP
#   ;/:
#   Imports/NNS
#   take/VBP
#   (NP blame/NN)
#   for/IN
#   (NP demise/NN)
#   of/IN
#   U.S./NNP
#   (NP car/NN)
#   brands/NNS
#   ,/,
#   but/CC
#   (NP overall/JJ variety/NN)
#   expands/VBZ
#   (NP economy/NN)
#   If/IN
#   you/PRP
#   're/VBP
#   (NP part/NN)
#   of/IN
#   the/DT
#   shrinking/VBG
#   (NP share/NN)
#   of/IN
#   Americans/NNPS
#   who/WP
#   still/RB
#   prefer/VBP
#   cars/NNS
#   to/TO
#   trucks/NNS
#   or/CC
#   SUVs/NNP
#   ,/,
#   I/PRP
#   have/VBP
#   (NP some/DT bad/JJ news/NN)
#   :/:
#   Your/PRP$
#   (NP world/NN)
#   is/VBZ
#   getting/VBG
#   smaller/JJR
#   ./.
#   Just/NNP
#   two/CD
#   years/NNS
#   ago/RB
#   ,/,
#   you/PRP
#   could/MD
#   choose/VB
#   from/IN
#   90/CD
#   different/JJ
#   models/NNS
#   ,/,
#   from/IN
#   large/JJ
#   to/TO
#   subcompact/VB
#   ./.
#   By/IN
#   (NP next/JJ year/NN)
#   ,/,
#   that/WDT
#   will/MD
#   shrivel/VB
#   to/TO
#   just/RB
#   62/CD
#   ./.
#   Some/DT
#   of/IN
#   the/DT
#   cars/NNS
#   that/WDT
#   will/MD
#   disappear/VB
#   from/IN
#   (NP the/DT lineup/NN)
#   ,/,
#   including/VBG
#   General/NNP
#   Motors/NNPS
#   Co./NNP
#   's/POS
#   Chevrolet/NNP
#   Cruze/NNP
#   and/CC
#   Ford/NNP
#   Motor/NNP
#   Co./NNP
#   's/POS
#   Focus/NNP
#   ,/,
#   will/MD
#   still/RB
#   be/VB
#   manufactured/VBN
#   and/CC
#   sold/VBN
#   overseas/RB
#   ;/:
#   they/PRP
#   just/RB
#   wo/MD
#   n't/RB
#   be/VB
#   available/JJ
#   to/TO
#   Americans/NNPS
#   ./.
#   This/DT
#   mostly/RB
#   reflects/VBZ
#   (NP a/DT strategic/JJ choice/NN)
#   :/:
#   GM/NNP
#   ,/,
#   Ford/NNP
#   and/CC
#   Fiat/NNP
#   Chrysler/NNP
#   Automobiles/NNP
#   NV/NNP
#   have/VBP
#   concluded/VBN
#   their/PRP$
#   (NP capital/NN)
#   is/VBZ
#   better/RBR
#   invested/VBN
#   in/IN
#   expanding/VBG
#   their/PRP$
#   (NP lineup/NN)
#   of/IN
#   (NP high-margin/NN)
#   trucks/NNS
#   and/CC
#   SUVs/NNP
#   and/CC
#   electric/JJ
#   and/CC
#   autonomous/JJ
#   cars/NNS
#   ,/,
#   rather/RB
#   than/IN
#   in/IN
#   (NP passenger/NN)
#   cars/NNS
#   ,/,
#   where/WRB
#   sales/NNS
#   are/VBP
#   sinking/VBG
#   and/CC
#   profits/NNS
#   are/VBP
#   razor-thin/JJ
#   ./.
#   But/CC
#   at/IN
#   (NP the/DT margin/NN)
#   ,/,
#   (NP a/DT shift/NN)
#   in/IN
#   (NP the/DT direction/NN)
#   of/IN
#   (NP globalization/NN)
#   is/VBZ
#   also/RB
#   at/IN
#   (NP work/NN)
#   ./.
#   Falling/VBG
#   (NP trade/NN)
#   barriers/NNS
#   enabled/VBD
#   multinational/JJ
#   companies/NNS
#   to/TO
#   integrate/VB
#   their/PRP$
#   (NP supply/NN)
#   chains/NNS
#   and/CC
#   rationalize/VB
#   operations/NNS
#   across/IN
#   borders/NNS
#   ,/,
#   to/TO
#   minimize/VB
#   costs/NNS
#   and/CC
#   maximize/VB
#   (NP product/NN)
#   offerings/NNS
#   ./.
#   In/IN
#   (NP the/DT process/NN)
#   ,/,
#   (NP some/DT American/JJ factory/NN)
#   workers/NNS
#   lost/VBD
#   their/PRP$
#   jobs/NNS
#   ./.
#   President/NNP
#   Trump/NNP
#   has/VBZ
#   promised/VBN
#   to/TO
#   bring/VB
#   them/PRP
#   back/RB
#   ,/,
#   and/CC
#   autos/NNS
#   have/VBP
#   long/RB
#   been/VBN
#   (NP a/DT priority/NN)
#   ./.
#   He/PRP
#   has/VBZ
#   reworked/VBN
#   (NP trade/NN)
#   treaties/NNS
#   to/TO
#   raise/VB
#   (NP the/DT bar/NN)
#   for/IN
#   tariff-free/JJ
#   imports/NNS
#   and/CC
#   harangued/VBN
#   manufacturers/NNS
#   who/WP
#   cut/VBD
#   (NP production/NN)
#   at/IN
#   (NP home/NN)
#   while/IN
#   boosting/VBG
#   it/PRP
#   abroad/RB
#   ./.
#   On/IN
#   Wednesday/NNP
#   ,/,
#   responding/VBG
#   to/TO
#   GM/NNP
#   's/POS
#   (NP decision/NN)
#   to/TO
#   idle/VB
#   several/JJ
#   U.S./NNP
#   factories/NNS
#   ,/,
#   including/VBG
#   one/CD
#   in/IN
#   Ohio/NNP
#   that/WDT
#   makes/VBZ
#   the/DT
#   Cruze/NNP
#   ,/,
#   Mr./NNP
#   Trump/NNP
#   renewed/VBD
#   (NP a/DT threat/NN)
#   to/TO
#   impose/VB
#   25/CD
#   (NP %/NN)
#   tariffs/NNS
#   on/IN
#   all/DT
#   imported/VBN
#   cars/NNS
#   ,/,
#   (NP predicting/NN)
#   ,/,
#   ``/``
#   many/JJ
#   more/JJR
#   cars/NNS
#   would/MD
#   be/VB
#   built/VBN
#   here/RB
#   ./.
#   ''/''
#   Yet/RB
#   many/JJ
#   now-imported/JJ
#   models/NNS
#   would/MD
#   sell/VB
#   too/RB
#   few/JJ
#   units/NNS
#   to/TO
#   justify/VB
#   (NP domestic/JJ production/NN)
#   ,/,
#   so/RB
#   (NP showroom/JJ selection/NN)
#   would/MD
#   almost/RB
#   certainly/RB
#   shrink/VBP
#   ./.
#   (NP The/DT traditional/JJ case/NN)
#   for/IN
#   (NP trade/NN)
#   was/VBD
#   that/IN
#   it/PRP
#   lets/VBZ
#   countries/NNS
#   specialize/VB
#   where/WRB
#   they/PRP
#   have/VBP
#   (NP a/DT comparative/JJ advantage/NN)
#   :/:
#   Portugal/NNP
#   in/IN
#   (NP wine/NN)
#   ,/,
#   England/NNP
#   in/IN
#   (NP cloth/NN)
#   ./.
#   But/CC
#   it/PRP
#   turns/VBZ
#   out/RP
#   that/IN
#   countries/NNS
#   benefit/VBP
#   even/RB
#   more/JJR
#   by/IN
#   (NP trading/NN)
#   similar/JJ
#   products/NNS
#   because/IN
#   of/IN
#   (NP the/DT great/JJ value/NN)
#   consumers/NNS
#   place/VBP
#   on/IN
#   (NP variety/NN)
#   ./.
#   Americans/NNPS
#   are/VBP
#   much/RB
#   more/RBR
#   likely/JJ
#   to/TO
#   find/VB
#   (NP the/DT perfect/JJ fit/NN)
#   for/IN
#   their/PRP$
#   tastes/NNS
#   if/IN
#   their/PRP$
#   choices/NNS
#   include/VBP
#   Scotch/NNP
#   (NP whisky/NN)
#   ,/,
#   (NP French/JJ cheese/NN)
#   and/CC
#   (NP Scandinavian/JJ crime/NN)
#   (NP fiction/NN)
#   ./.
#   This/DT
#   is/VBZ
#   especially/RB
#   true/JJ
#   with/IN
#   products/NNS
#   such/JJ
#   as/IN
#   cars/NNS
#   that/IN
#   require/VBP
#   steep/JJ
#   up-front/JJ
#   investments/NNS
#   and/CC
#   economies/NNS
#   of/IN
#   (NP scale/NN)
#   :/:
#   A/DT
#   larger/JJR
#   (NP transnational/JJ market/NN)
#   can/MD
#   support/VB
#   more/JJR
#   brands/NNS
#   and/CC
#   models/NNS
#   than/IN
#   several/JJ
#   isolated/JJ
#   national/JJ
#   markets/NNS
#   ./.
#   Trade/NNP
#   (NP data/NN)
#   does/VBZ
#   n't/RB
#   fully/RB
#   capture/VB
#   (NP the/DT benefit/NN)
#   of/IN
#   (NP variety/NN)
#   ./.
#   For/IN
#   (NP example/NN)
#   ,/,
#   if/IN
#   only/RB
#   (NP red/JJ wine/NN)
#   is/VBZ
#   made/VBN
#   domestically/RB
#   ,/,
#   (NP access/NN)
#   to/TO
#   imported/VBN
#   white/JJ
#   is/VBZ
#   quite/RB
#   desirable/JJ
#   --/:
#   but/CC
#   tough/JJ
#   to/TO
#   (NP value/NN)
#   ./.
#   Between/JJ
#   1972/CD
#   and/CC
#   2001/CD
#   ,/,
#   (NP the/DT range/NN)
#   of/IN
#   products/NNS
#   imported/VBN
#   by/IN
#   the/DT
#   U.S./NNP
#   grew/VBD
#   fourfold/RB
#   ,/,
#   according/VBG
#   to/TO
#   a/DT
#   2004/CD
#   (NP paper/NN)
#   by/IN
#   David/NNP
#   Weinstein/NNP
#   of/IN
#   Columbia/NNP
#   University/NNP
#   and/CC
#   Christian/NNP
#   Broda/NNP
#   ,/,
#   then/RB
#   at/IN
#   the/DT
#   Federal/NNP
#   Reserve/NNP
#   Bank/NNP
#   of/IN
#   New/NNP
#   York/NNP
#   ./.
#   They/PRP
#   put/VBD
#   (NP the/DT unmeasured/JJ value/NN)
#   of/IN
#   this/DT
#   increased/VBN
#   (NP variety/NN)
#   at/IN
#   2.8/CD
#   (NP %/NN)
#   of/IN
#   (NP gross/JJ domestic/JJ product/NN)
#   ./.
#   (NP Last/JJ year/NN)
#   (NP a/DT team/NN)
#   of/IN
#   economists/NNS
#   at/IN
#   the/DT
#   New/NNP
#   York/NNP
#   Fed/NNP
#   found/VBD
#   that/IN
#   85/CD
#   (NP %/NN)
#   of/IN
#   (NP the/DT increase/NN)
#   in/IN
#   imports/NNS
#   from/IN
#   China/NNP
#   between/IN
#   2000/CD
#   and/CC
#   2006/CD
#   came/VBD
#   from/IN
#   products/NNS
#   that/WDT
#   had/VBD
#   never/RB
#   been/VBN
#   imported/VBN
#   before/IN
#   ,/,
#   delivering/VBG
#   (NP a/DT substantial/JJ unmeasured/JJ benefit/NN)
#   through/IN
#   greater/JJR
#   (NP variety/NN)
#   ./.
#   The/DT
#   U.S./NNP
#   (NP car/NN)
#   (NP market/NN)
#   is/VBZ
#   (NP a/DT prime/JJ example/NN)
#   of/IN
#   the/DT
#   benefits/NNS
#   of/IN
#   imported/VBN
#   (NP variety/NN)
#   ./.
#   Kristin/NNP
#   Dziczek/NNP
#   ,/,
#   (NP an/DT economist/NN)
#   at/IN
#   the/DT
#   industry-backed/JJ
#   Center/NNP
#   for/IN
#   Automotive/NNP
#   Research/NNP
#   ,/,
#   says/VBZ
#   it/PRP
#   's/VBZ
#   ``/``
#   unbelievably/RB
#   hard/JJ
#   ''/''
#   for/IN
#   American/JJ
#   manufacturers/NNS
#   to/TO
#   make/VB
#   cars/NNS
#   profitably/RB
#   ,/,
#   (NP no/DT matter/NN)
#   how/WRB
#   much/RB
#   they/PRP
#   automate/VBP
#   or/CC
#   what/WP
#   concessions/NNS
#   their/PRP$
#   unions/NNS
#   offer/VBP
#   ./.
#   A/DT
#   growing/VBG
#   (NP share/NN)
#   of/IN
#   cars/NNS
#   is/VBZ
#   thus/RB
#   made/VBN
#   by/IN
#   foreign/JJ
#   companies/NNS
#   ,/,
#   imported/VBN
#   ,/,
#   or/CC
#   both/DT
#   ./.
#   According/VBG
#   to/TO
#   Edmunds.com/NNP
#   ,/,
#   19/CD
#   of/IN
#   20/CD
#   (NP subcompact/NN)
#   and/CC
#   17/CD
#   of/IN
#   27/CD
#   compact/JJ
#   cars/NNS
#   offered/VBN
#   in/IN
#   the/DT
#   U.S./NNP
#   are/VBP
#   imported/VBN
#   ./.
#   (NP Early/JJ last/JJ year/NN)
#   Ford/NNP
#   scrapped/VBD
#   plans/NNS
#   to/TO
#   move/VB
#   (NP production/NN)
#   of/IN
#   the/DT
#   Focus/NNP
#   from/IN
#   Michigan/NNP
#   to/TO
#   Mexico/NNP
#   after/IN
#   (NP criticism/NN)
#   from/IN
#   then-President-elect/JJ
#   Trump/NNP
#   ./.
#   Ford/NNP
#   then/RB
#   sought/VBD
#   to/TO
#   import/VB
#   it/PRP
#   from/IN
#   (NP an/DT underutilized/JJ plant/NN)
#   in/IN
#   China/NNP
#   ,/,
#   but/CC
#   dropped/VBD
#   that/IN
#   (NP plan/NN)
#   after/IN
#   Mr./NNP
#   Trump/NNP
#   imposed/VBD
#   a/DT
#   25/CD
#   (NP %/NN)
#   (NP tariff/NN)
#   on/IN
#   Chinese/JJ
#   imports/NNS
#   ./.
#   It/PRP
#   now/RB
#   plans/VBZ
#   to/TO
#   discontinue/VB
#   offering/VBG
#   (NP the/DT car/NN)
#   in/IN
#   the/DT
#   U.S./NNP
#   (NP Last/JJ year/NN)
#   Mr./NNP
#   Trump/NNP
#   also/RB
#   lit/VBD
#   into/IN
#   GM/NNP
#   for/IN
#   importing/VBG
#   the/DT
#   Cruze/NNP
#   from/IN
#   Mexico/NNP
#   ./.
#   This/DT
#   was/VBD
#   (NP a/DT misfire/NN)
#   :/:
#   GM/NNP
#   only/RB
#   imports/VBZ
#   (NP the/DT hatchback/NN)
#   (NP version/NN)
#   ,/,
#   (NP a/DT fraction/NN)
#   of/IN
#   U.S./NNP
#   sales/NNS
#   ,/,
#   from/IN
#   Mexico/NNP
#   ./.
#   Sedans/NNS
#   sold/VBN
#   in/IN
#   the/DT
#   U.S./NNP
#   are/VBP
#   made/VBN
#   in/IN
#   Ohio/NNP
#   ./.
#   Once/NNP
#   (NP production/NN)
#   ends/NNS
#   ,/,
#   GM/NNP
#   wo/MD
#   n't/RB
#   import/VB
#   the/DT
#   Cruze/NNP
#   :/:
#   It/PRP
#   will/MD
#   just/RB
#   stop/VB
#   selling/VBG
#   it/PRP
#   ./.
#   ``/``
#   It/PRP
#   's/VBZ
#   (NP a/DT question/NN)
#   of/IN
#   (NP resource/NN)
#   (NP allocation/NN)
#   :/:
#   We/PRP
#   'd/MD
#   rather/RB
#   invest/VB
#   in/IN
#   higher/JJR
#   (NP growth/NN)
#   opportunities/NNS
#   across/IN
#   (NP the/DT company/NN)
#   ,/,
#   ''/''
#   (NP a/DT spokesman/NN)
#   says/VBZ
#   ./.
#   Still/RB
#   ,/,
#   GM/NNP
#   will/MD
#   continue/VB
#   to/TO
#   sell/VB
#   Mexican-made/NNP
#   Cruzes/NNP
#   in/IN
#   Latin/NNP
#   America/NNP
#   and/CC
#   Israel/NNP
#   and/CC
#   ,/,
#   possibly/RB
#   ,/,
#   Canada/NNP
#   ./.
#   While/IN
#   GM/NNP
#   did/VBD
#   n't/RB
#   cite/VB
#   tariffs/NNS
#   or/CC
#   (NP trade/NN)
#   tensions/NNS
#   as/IN
#   driving/VBG
#   its/PRP$
#   decisions/NNS
#   ,/,
#   they/PRP
#   clearly/RB
#   did/VBD
#   n't/RB
#   help/VB
#   :/:
#   Tariffs/VB
#   on/IN
#   (NP steel/NN)
#   ,/,
#   (NP aluminum/NN)
#   and/CC
#   imported/VBN
#   Chinese/JJ
#   parts/NNS
#   all/DT
#   eat/VBP
#   into/IN
#   what/WP
#   are/VBP
#   already/RB
#   thin/JJ
#   margins/NNS
#   on/IN
#   cars/NNS
#   in/IN
#   the/DT
#   U.S./NNP
#   That/IN
#   Mr./NNP
#   Trump/NNP
#   's/POS
#   (NP trade/NN)
#   tactics/NNS
#   sometimes/RB
#   hurt/VBP
#   consumers/NNS
#   does/VBZ
#   n't/RB
#   make/VB
#   them/PRP
#   wrong/JJ
#   :/:
#   It/PRP
#   may/MD
#   be/VB
#   (NP a/DT necessary/JJ price/NN)
#   if/IN
#   Mr./NNP
#   Trump/NNP
#   is/VBZ
#   to/TO
#   coax/VB
#   foreign/JJ
#   countries/NNS
#   into/IN
#   concessions/NNS
#   that/WDT
#   lower/VBP
#   the/DT
#   barriers/NNS
#   to/TO
#   American/JJ
#   companies/NNS
#   ,/,
#   workers/NNS
#   and/CC
#   exporters/NNS
#   ./.
#   But/CC
#   in/IN
#   (NP the/DT end/NN)
#   ,/,
#   consumers/NNS
#   have/VBP
#   to/TO
#   have/VB
#   more/JJR
#   to/TO
#   choose/VB
#   from/IN
#   than/IN
#   before/IN
#   ;/:
#   otherwise/RB
#   ,/,
#   they/PRP
#   'll/MD
#   be/VB
#   losers/NNS
#   ./.)

# %%
tree1 = nltk.Tree('NP',['Alick'])
print(tree1)
tree2 = nltk.Tree('N',['Alick','Rabbit'])
print(tree2)
tree3 = nltk.Tree('S',[tree1,tree2])
print(tree3.label())
tree3.draw()
# Out:
# (NP Alick)
# (N Alick Rabbit)
# S

# %%
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)

# %%
type(NER)
# Out:
# nltk.tree.Tree

# %%
print(NER)
# Out:
# (S
#   (ORGANIZATION Consumer/NN)
#   (PERSON Beware/NNP)
#   :/:
#   With/IN
#   (PERSON Less/NNP Trade/NNP Comes/NNP Less/NNP Choice/NNP)
#   ;/:
#   Imports/NNS
#   take/VBP
#   blame/NN
#   for/IN
#   demise/NN
#   of/IN
#   (GPE U.S./NNP)
#   car/NN
#   brands/NNS
#   ,/,
#   but/CC
#   overall/JJ
#   variety/NN
#   expands/VBZ
#   economy/NN
#   If/IN
#   you/PRP
#   're/VBP
#   part/NN
#   of/IN
#   the/DT
#   shrinking/VBG
#   share/NN
#   of/IN
#   Americans/NNPS
#   who/WP
#   still/RB
#   prefer/VBP
#   cars/NNS
#   to/TO
#   trucks/NNS
#   or/CC
#   (ORGANIZATION SUVs/NNP)
#   ,/,
#   I/PRP
#   have/VBP
#   some/DT
#   bad/JJ
#   news/NN
#   :/:
#   Your/PRP$
#   world/NN
#   is/VBZ
#   getting/VBG
#   smaller/JJR
#   ./.
#   Just/NNP
#   two/CD
#   years/NNS
#   ago/RB
#   ,/,
#   you/PRP
#   could/MD
#   choose/VB
#   from/IN
#   90/CD
#   different/JJ
#   models/NNS
#   ,/,
#   from/IN
#   large/JJ
#   to/TO
#   subcompact/VB
#   ./.
#   By/IN
#   next/JJ
#   year/NN
#   ,/,
#   that/WDT
#   will/MD
#   shrivel/VB
#   to/TO
#   just/RB
#   62/CD
#   ./.
#   Some/DT
#   of/IN
#   the/DT
#   cars/NNS
#   that/WDT
#   will/MD
#   disappear/VB
#   from/IN
#   the/DT
#   lineup/NN
#   ,/,
#   including/VBG
#   (ORGANIZATION General/NNP Motors/NNPS Co./NNP)
#   's/POS
#   (PERSON Chevrolet/NNP Cruze/NNP)
#   and/CC
#   (ORGANIZATION Ford/NNP Motor/NNP)
#   Co./NNP
#   's/POS
#   (PERSON Focus/NNP)
#   ,/,
#   will/MD
#   still/RB
#   be/VB
#   manufactured/VBN
#   and/CC
#   sold/VBN
#   overseas/RB
#   ;/:
#   they/PRP
#   just/RB
#   wo/MD
#   n't/RB
#   be/VB
#   available/JJ
#   to/TO
#   (GPE Americans/NNPS)
#   ./.
#   This/DT
#   mostly/RB
#   reflects/VBZ
#   a/DT
#   strategic/JJ
#   choice/NN
#   :/:
#   GM/NNP
#   ,/,
#   (ORGANIZATION Ford/NNP)
#   and/CC
#   (PERSON Fiat/NNP Chrysler/NNP Automobiles/NNP)
#   NV/NNP
#   have/VBP
#   concluded/VBN
#   their/PRP$
#   capital/NN
#   is/VBZ
#   better/RBR
#   invested/VBN
#   in/IN
#   expanding/VBG
#   their/PRP$
#   lineup/NN
#   of/IN
#   high-margin/NN
#   trucks/NNS
#   and/CC
#   (ORGANIZATION SUVs/NNP)
#   and/CC
#   electric/JJ
#   and/CC
#   autonomous/JJ
#   cars/NNS
#   ,/,
#   rather/RB
#   than/IN
#   in/IN
#   passenger/NN
#   cars/NNS
#   ,/,
#   where/WRB
#   sales/NNS
#   are/VBP
#   sinking/VBG
#   and/CC
#   profits/NNS
#   are/VBP
#   razor-thin/JJ
#   ./.
#   But/CC
#   at/IN
#   the/DT
#   margin/NN
#   ,/,
#   a/DT
#   shift/NN
#   in/IN
#   the/DT
#   direction/NN
#   of/IN
#   globalization/NN
#   is/VBZ
#   also/RB
#   at/IN
#   work/NN
#   ./.
#   Falling/VBG
#   trade/NN
#   barriers/NNS
#   enabled/VBD
#   multinational/JJ
#   companies/NNS
#   to/TO
#   integrate/VB
#   their/PRP$
#   supply/NN
#   chains/NNS
#   and/CC
#   rationalize/VB
#   operations/NNS
#   across/IN
#   borders/NNS
#   ,/,
#   to/TO
#   minimize/VB
#   costs/NNS
#   and/CC
#   maximize/VB
#   product/NN
#   offerings/NNS
#   ./.
#   In/IN
#   the/DT
#   process/NN
#   ,/,
#   some/DT
#   (GPE American/JJ)
#   factory/NN
#   workers/NNS
#   lost/VBD
#   their/PRP$
#   jobs/NNS
#   ./.
#   President/NNP
#   (PERSON Trump/NNP)
#   has/VBZ
#   promised/VBN
#   to/TO
#   bring/VB
#   them/PRP
#   back/RB
#   ,/,
#   and/CC
#   autos/NNS
#   have/VBP
#   long/RB
#   been/VBN
#   a/DT
#   priority/NN
#   ./.
#   He/PRP
#   has/VBZ
#   reworked/VBN
#   trade/NN
#   treaties/NNS
#   to/TO
#   raise/VB
#   the/DT
#   bar/NN
#   for/IN
#   tariff-free/JJ
#   imports/NNS
#   and/CC
#   harangued/VBN
#   manufacturers/NNS
#   who/WP
#   cut/VBD
#   production/NN
#   at/IN
#   home/NN
#   while/IN
#   boosting/VBG
#   it/PRP
#   abroad/RB
#   ./.
#   On/IN
#   Wednesday/NNP
#   ,/,
#   responding/VBG
#   to/TO
#   (ORGANIZATION GM/NNP)
#   's/POS
#   decision/NN
#   to/TO
#   idle/VB
#   several/JJ
#   (GPE U.S./NNP)
#   factories/NNS
#   ,/,
#   including/VBG
#   one/CD
#   in/IN
#   (GPE Ohio/NNP)
#   that/WDT
#   makes/VBZ
#   the/DT
#   (GPE Cruze/NNP)
#   ,/,
#   (PERSON Mr./NNP Trump/NNP)
#   renewed/VBD
#   a/DT
#   threat/NN
#   to/TO
#   impose/VB
#   25/CD
#   %/NN
#   tariffs/NNS
#   on/IN
#   all/DT
#   imported/VBN
#   cars/NNS
#   ,/,
#   predicting/NN
#   ,/,
#   ``/``
#   many/JJ
#   more/JJR
#   cars/NNS
#   would/MD
#   be/VB
#   built/VBN
#   here/RB
#   ./.
#   ''/''
#   Yet/RB
#   many/JJ
#   now-imported/JJ
#   models/NNS
#   would/MD
#   sell/VB
#   too/RB
#   few/JJ
#   units/NNS
#   to/TO
#   justify/VB
#   domestic/JJ
#   production/NN
#   ,/,
#   so/RB
#   showroom/JJ
#   selection/NN
#   would/MD
#   almost/RB
#   certainly/RB
#   shrink/VBP
#   ./.
#   The/DT
#   traditional/JJ
#   case/NN
#   for/IN
#   trade/NN
#   was/VBD
#   that/IN
#   it/PRP
#   lets/VBZ
#   countries/NNS
#   specialize/VB
#   where/WRB
#   they/PRP
#   have/VBP
#   a/DT
#   comparative/JJ
#   advantage/NN
#   :/:
#   (GPE Portugal/NNP)
#   in/IN
#   wine/NN
#   ,/,
#   (GPE England/NNP)
#   in/IN
#   cloth/NN
#   ./.
#   But/CC
#   it/PRP
#   turns/VBZ
#   out/RP
#   that/IN
#   countries/NNS
#   benefit/VBP
#   even/RB
#   more/JJR
#   by/IN
#   trading/NN
#   similar/JJ
#   products/NNS
#   because/IN
#   of/IN
#   the/DT
#   great/JJ
#   value/NN
#   consumers/NNS
#   place/VBP
#   on/IN
#   variety/NN
#   ./.
#   Americans/NNPS
#   are/VBP
#   much/RB
#   more/RBR
#   likely/JJ
#   to/TO
#   find/VB
#   the/DT
#   perfect/JJ
#   fit/NN
#   for/IN
#   their/PRP$
#   tastes/NNS
#   if/IN
#   their/PRP$
#   choices/NNS
#   include/VBP
#   (GPE Scotch/NNP)
#   whisky/NN
#   ,/,
#   (GPE French/JJ)
#   cheese/NN
#   and/CC
#   (GPE Scandinavian/JJ)
#   crime/NN
#   fiction/NN
#   ./.
#   This/DT
#   is/VBZ
#   especially/RB
#   true/JJ
#   with/IN
#   products/NNS
#   such/JJ
#   as/IN
#   cars/NNS
#   that/IN
#   require/VBP
#   steep/JJ
#   up-front/JJ
#   investments/NNS
#   and/CC
#   economies/NNS
#   of/IN
#   scale/NN
#   :/:
#   A/DT
#   larger/JJR
#   transnational/JJ
#   market/NN
#   can/MD
#   support/VB
#   more/JJR
#   brands/NNS
#   and/CC
#   models/NNS
#   than/IN
#   several/JJ
#   isolated/JJ
#   national/JJ
#   markets/NNS
#   ./.
#   (PERSON Trade/NNP)
#   data/NN
#   does/VBZ
#   n't/RB
#   fully/RB
#   capture/VB
#   the/DT
#   benefit/NN
#   of/IN
#   variety/NN
#   ./.
#   For/IN
#   example/NN
#   ,/,
#   if/IN
#   only/RB
#   red/JJ
#   wine/NN
#   is/VBZ
#   made/VBN
#   domestically/RB
#   ,/,
#   access/NN
#   to/TO
#   imported/VBN
#   white/JJ
#   is/VBZ
#   quite/RB
#   desirable/JJ
#   --/:
#   but/CC
#   tough/JJ
#   to/TO
#   value/NN
#   ./.
#   Between/JJ
#   1972/CD
#   and/CC
#   2001/CD
#   ,/,
#   the/DT
#   range/NN
#   of/IN
#   products/NNS
#   imported/VBN
#   by/IN
#   the/DT
#   (GPE U.S./NNP)
#   grew/VBD
#   fourfold/RB
#   ,/,
#   according/VBG
#   to/TO
#   a/DT
#   2004/CD
#   paper/NN
#   by/IN
#   (PERSON David/NNP Weinstein/NNP)
#   of/IN
#   (ORGANIZATION Columbia/NNP University/NNP)
#   and/CC
#   (PERSON Christian/NNP Broda/NNP)
#   ,/,
#   then/RB
#   at/IN
#   the/DT
#   (ORGANIZATION Federal/NNP Reserve/NNP Bank/NNP)
#   of/IN
#   (GPE New/NNP York/NNP)
#   ./.
#   They/PRP
#   put/VBD
#   the/DT
#   unmeasured/JJ
#   value/NN
#   of/IN
#   this/DT
#   increased/VBN
#   variety/NN
#   at/IN
#   2.8/CD
#   %/NN
#   of/IN
#   gross/JJ
#   domestic/JJ
#   product/NN
#   ./.
#   Last/JJ
#   year/NN
#   a/DT
#   team/NN
#   of/IN
#   economists/NNS
#   at/IN
#   the/DT
#   (GPE New/NNP York/NNP)
#   Fed/NNP
#   found/VBD
#   that/IN
#   85/CD
#   %/NN
#   of/IN
#   the/DT
#   increase/NN
#   in/IN
#   imports/NNS
#   from/IN
#   (GPE China/NNP)
#   between/IN
#   2000/CD
#   and/CC
#   2006/CD
#   came/VBD
#   from/IN
#   products/NNS
#   that/WDT
#   had/VBD
#   never/RB
#   been/VBN
#   imported/VBN
#   before/IN
#   ,/,
#   delivering/VBG
#   a/DT
#   substantial/JJ
#   unmeasured/JJ
#   benefit/NN
#   through/IN
#   greater/JJR
#   variety/NN
#   ./.
#   The/DT
#   (GPE U.S./NNP)
#   car/NN
#   market/NN
#   is/VBZ
#   a/DT
#   prime/JJ
#   example/NN
#   of/IN
#   the/DT
#   benefits/NNS
#   of/IN
#   imported/VBN
#   variety/NN
#   ./.
#   (PERSON Kristin/NNP Dziczek/NNP)
#   ,/,
#   an/DT
#   economist/NN
#   at/IN
#   the/DT
#   industry-backed/JJ
#   (ORGANIZATION Center/NNP)
#   for/IN
#   (ORGANIZATION Automotive/NNP Research/NNP)
#   ,/,
#   says/VBZ
#   it/PRP
#   's/VBZ
#   ``/``
#   unbelievably/RB
#   hard/JJ
#   ''/''
#   for/IN
#   (GPE American/JJ)
#   manufacturers/NNS
#   to/TO
#   make/VB
#   cars/NNS
#   profitably/RB
#   ,/,
#   no/DT
#   matter/NN
#   how/WRB
#   much/RB
#   they/PRP
#   automate/VBP
#   or/CC
#   what/WP
#   concessions/NNS
#   their/PRP$
#   unions/NNS
#   offer/VBP
#   ./.
#   A/DT
#   growing/VBG
#   share/NN
#   of/IN
#   cars/NNS
#   is/VBZ
#   thus/RB
#   made/VBN
#   by/IN
#   foreign/JJ
#   companies/NNS
#   ,/,
#   imported/VBN
#   ,/,
#   or/CC
#   both/DT
#   ./.
#   According/VBG
#   to/TO
#   Edmunds.com/NNP
#   ,/,
#   19/CD
#   of/IN
#   20/CD
#   subcompact/NN
#   and/CC
#   17/CD
#   of/IN
#   27/CD
#   compact/JJ
#   cars/NNS
#   offered/VBN
#   in/IN
#   the/DT
#   (GPE U.S./NNP)
#   are/VBP
#   imported/VBN
#   ./.
#   Early/JJ
#   last/JJ
#   year/NN
#   Ford/NNP
#   scrapped/VBD
#   plans/NNS
#   to/TO
#   move/VB
#   production/NN
#   of/IN
#   the/DT
#   Focus/NNP
#   from/IN
#   (GPE Michigan/NNP)
#   to/TO
#   (GPE Mexico/NNP)
#   after/IN
#   criticism/NN
#   from/IN
#   then-President-elect/JJ
#   Trump/NNP
#   ./.
#   Ford/NNP
#   then/RB
#   sought/VBD
#   to/TO
#   import/VB
#   it/PRP
#   from/IN
#   an/DT
#   underutilized/JJ
#   plant/NN
#   in/IN
#   (GPE China/NNP)
#   ,/,
#   but/CC
#   dropped/VBD
#   that/IN
#   plan/NN
#   after/IN
#   (PERSON Mr./NNP Trump/NNP)
#   imposed/VBD
#   a/DT
#   25/CD
#   %/NN
#   tariff/NN
#   on/IN
#   (GPE Chinese/JJ)
#   imports/NNS
#   ./.
#   It/PRP
#   now/RB
#   plans/VBZ
#   to/TO
#   discontinue/VB
#   offering/VBG
#   the/DT
#   car/NN
#   in/IN
#   the/DT
#   (GPE U.S./NNP)
#   Last/JJ
#   year/NN
#   (PERSON Mr./NNP Trump/NNP)
#   also/RB
#   lit/VBD
#   into/IN
#   (ORGANIZATION GM/NNP)
#   for/IN
#   importing/VBG
#   the/DT
#   Cruze/NNP
#   from/IN
#   (GPE Mexico/NNP)
#   ./.
#   This/DT
#   was/VBD
#   a/DT
#   misfire/NN
#   :/:
#   GM/NNP
#   only/RB
#   imports/VBZ
#   the/DT
#   hatchback/NN
#   version/NN
#   ,/,
#   a/DT
#   fraction/NN
#   of/IN
#   (GPE U.S./NNP)
#   sales/NNS
#   ,/,
#   from/IN
#   (GPE Mexico/NNP)
#   ./.
#   Sedans/NNS
#   sold/VBN
#   in/IN
#   the/DT
#   (GPE U.S./NNP)
#   are/VBP
#   made/VBN
#   in/IN
#   (GPE Ohio/NNP)
#   ./.
#   Once/NNP
#   production/NN
#   ends/NNS
#   ,/,
#   (ORGANIZATION GM/NNP)
#   wo/MD
#   n't/RB
#   import/VB
#   the/DT
#   Cruze/NNP
#   :/:
#   It/PRP
#   will/MD
#   just/RB
#   stop/VB
#   selling/VBG
#   it/PRP
#   ./.
#   ``/``
#   It/PRP
#   's/VBZ
#   a/DT
#   question/NN
#   of/IN
#   resource/NN
#   allocation/NN
#   :/:
#   We/PRP
#   'd/MD
#   rather/RB
#   invest/VB
#   in/IN
#   higher/JJR
#   growth/NN
#   opportunities/NNS
#   across/IN
#   the/DT
#   company/NN
#   ,/,
#   ''/''
#   a/DT
#   spokesman/NN
#   says/VBZ
#   ./.
#   Still/RB
#   ,/,
#   (ORGANIZATION GM/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   sell/VB
#   Mexican-made/NNP
#   Cruzes/NNP
#   in/IN
#   (GPE Latin/NNP America/NNP)
#   and/CC
#   (GPE Israel/NNP)
#   and/CC
#   ,/,
#   possibly/RB
#   ,/,
#   (GPE Canada/NNP)
#   ./.
#   While/IN
#   (ORGANIZATION GM/NNP)
#   did/VBD
#   n't/RB
#   cite/VB
#   tariffs/NNS
#   or/CC
#   trade/NN
#   tensions/NNS
#   as/IN
#   driving/VBG
#   its/PRP$
#   decisions/NNS
#   ,/,
#   they/PRP
#   clearly/RB
#   did/VBD
#   n't/RB
#   help/VB
#   :/:
#   Tariffs/VB
#   on/IN
#   steel/NN
#   ,/,
#   aluminum/NN
#   and/CC
#   imported/VBN
#   (GPE Chinese/JJ)
#   parts/NNS
#   all/DT
#   eat/VBP
#   into/IN
#   what/WP
#   are/VBP
#   already/RB
#   thin/JJ
#   margins/NNS
#   on/IN
#   cars/NNS
#   in/IN
#   the/DT
#   (GPE U.S./NNP)
#   That/IN
#   (PERSON Mr./NNP Trump/NNP)
#   's/POS
#   trade/NN
#   tactics/NNS
#   sometimes/RB
#   hurt/VBP
#   consumers/NNS
#   does/VBZ
#   n't/RB
#   make/VB
#   them/PRP
#   wrong/JJ
#   :/:
#   It/PRP
#   may/MD
#   be/VB
#   a/DT
#   necessary/JJ
#   price/NN
#   if/IN
#   (PERSON Mr./NNP Trump/NNP)
#   is/VBZ
#   to/TO
#   coax/VB
#   foreign/JJ
#   countries/NNS
#   into/IN
#   concessions/NNS
#   that/WDT
#   lower/VBP
#   the/DT
#   barriers/NNS
#   to/TO
#   (GPE American/JJ)
#   companies/NNS
#   ,/,
#   workers/NNS
#   and/CC
#   exporters/NNS
#   ./.
#   But/CC
#   in/IN
#   the/DT
#   end/NN
#   ,/,
#   consumers/NNS
#   have/VBP
#   to/TO
#   have/VB
#   more/JJR
#   to/TO
#   choose/VB
#   from/IN
#   than/IN
#   before/IN
#   ;/:
#   otherwise/RB
#   ,/,
#   they/PRP
#   'll/MD
#   be/VB
#   losers/NNS
#   ./.)

# %%
def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'GPE')
# Out:
# ['U.S.',
#  'Americans',
#  'American',
#  'U.S. Ohio',
#  'Cruze',
#  'Portugal',
#  'England',
#  'Scotch',
#  'French',
#  'Scandinavian',
#  'U.S. New York',
#  'New York',
#  'China',
#  'U.S. American',
#  'U.S. Michigan',
#  'Mexico',
#  'China Chinese',
#  'U.S. Mexico',
#  'U.S. Mexico U.S.',
#  'Ohio',
#  'Latin America',
#  'Israel',
#  'Canada',
#  'Chinese']

# %%
get_continuous_chunks(strEx, 'ORGANIZATION')
# Out:
# ['Consumer',
#  'SUVs',
#  'General Motors Co.',
#  'Ford Motor',
#  'Ford',
#  'SUVs GM',
#  'Columbia University',
#  'Federal Reserve Bank',
#  'Center',
#  'Automotive Research',
#  'GM',
#  'GM GM']
